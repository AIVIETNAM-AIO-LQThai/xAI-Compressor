# %% [markdown]
# # Regime Calibration and Routing Instability Audit
#
# This notebook is a lightweight companion to the frozen script. The authoritative audit is run with:
#
# `python -m scripts.audit_regime_calibration`
#
# The study loads TRAIN and CALIBRATION only. TEST and incident labels must remain unloaded.

# %%
import json
from pathlib import Path

ROOT = Path('..') if Path.cwd().name == 'notebooks' else Path('.')
result_path = ROOT / 'docs/research/regime_calibration_audit.json'
print(result_path)
if result_path.exists():
    result = json.loads(result_path.read_text(encoding='utf-8'))
    result['candidate_reproduction']
