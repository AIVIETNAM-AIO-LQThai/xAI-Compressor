# %% [markdown]
# # Operating-Cycle Support Audit
#
# Authoritative execution:
#
# `python -m scripts.audit_operating_cycle_support`
#
# Post-hoc reused-TEST diagnostic. No new router or detector is evaluated.
