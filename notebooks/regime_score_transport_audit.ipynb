# %% [markdown]
# # Regime-PCA Score Transport Audit
#
# Authoritative execution:
#
# `python -m scripts.audit_regime_score_transport`
#
# This is a post-hoc reused-TEST diagnostic. It changes no detector or alert rule.
