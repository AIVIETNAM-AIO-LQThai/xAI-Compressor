# %% [markdown]
# # Regime-Transition EWMA Carryover Audit
#
# Authoritative execution:
#
# `python -m scripts.audit_regime_ewma_carryover`
#
# TRAIN + CALIBRATION only. TEST and incidents are excluded.
