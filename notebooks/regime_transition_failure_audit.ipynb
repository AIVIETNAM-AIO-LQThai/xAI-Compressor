# %% [markdown]
# # Transition-Reset Candidate Failure Audit
#
# Authoritative execution:
#
# `python -m scripts.audit_regime_transition_failure`
#
# This is a post-hoc reused-TEST diagnostic. No alternative alert rule is simulated.
