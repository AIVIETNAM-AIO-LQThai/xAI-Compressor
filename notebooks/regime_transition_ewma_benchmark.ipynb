# %% [markdown]
# # Regime-Transition EWMA Candidate Benchmark
#
# Authoritative execution:
#
# `python -m scripts.benchmark_regime_transition_ewma`
#
# This is an exploratory reused-test benchmark. Do not tune after viewing results.
