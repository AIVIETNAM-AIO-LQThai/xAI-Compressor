# %% [markdown]
# # Coverage-Conditioned Stationarity Audit
#
# Authoritative execution:
#
# `python -m scripts.audit_coverage_conditioned_stationarity`
#
# Post-hoc reused-TEST diagnostic. Conditioning is descriptive only; no detector rows are removed.
