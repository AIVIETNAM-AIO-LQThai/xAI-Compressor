# %% [markdown]
# # Feature Stationarity / Shortcut Audit
#
# Authoritative execution:
#
# `python -m scripts.audit_feature_stationarity_shortcut`
#
# This is a post-hoc reused-TEST diagnostic. No feature or detector is changed.
